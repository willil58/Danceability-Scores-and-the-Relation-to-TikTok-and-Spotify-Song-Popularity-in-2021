# %% [markdown]
# import the libraries I need and the first data set I will be using which is for Spotify

# %%
import pandas as pd
import numpy as np

sdf = pd.read_csv('/Users/Leah/Desktop/spotify_top50_2021.csv')

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# look at the headers for Spotify data

# %%
sdf.head()
# Out:
#    id     artist_name                      track_name                track_id  \
# 0   1  Olivia Rodrigo                 drivers license  5wANPM4fQCJwkGd4rN57mH
# 1   2       Lil Nas X  MONTERO (Call Me By Your Name)  1SC5rEoYDGUK4NfG82494W
# 2   3   The Kid LAROI       STAY (with Justin Bieber)  5PjdY0CKGZdEuoNab3yDmX
# 3   4  Olivia Rodrigo                        good 4 u  4ZtFanR9U6ndgddUvNcjcG
# 4   5        Dua Lipa       Levitating (feat. DaBaby)  5nujrmhLynf4yMoMtj8AQF
#
#    popularity  danceability  energy  key  loudness  mode  speechiness  \
# 0          92         0.561   0.431   10    -8.810     1       0.0578
# 1          90         0.593   0.503    8    -6.725     0       0.2200
# 2          92         0.591   0.764    1    -5.484     1       0.0483
# 3          95         0.563   0.664    9    -5.044     1       0.1540
# 4          89         0.702   0.825    6    -3.787     0       0.0601
#
# ...

# %% [markdown]
# rename spotify popularity header to spotify popularity

# %%
sdf.rename(columns = {'popularity':'spotify popularity'}, inplace = True)

# %% [markdown]
# check that the renaming worked

# %%
sdf.head()
# Out:
#    id     artist_name                      track_name                track_id  \
# 0   1  Olivia Rodrigo                 drivers license  5wANPM4fQCJwkGd4rN57mH
# 1   2       Lil Nas X  MONTERO (Call Me By Your Name)  1SC5rEoYDGUK4NfG82494W
# 2   3   The Kid LAROI       STAY (with Justin Bieber)  5PjdY0CKGZdEuoNab3yDmX
# 3   4  Olivia Rodrigo                        good 4 u  4ZtFanR9U6ndgddUvNcjcG
# 4   5        Dua Lipa       Levitating (feat. DaBaby)  5nujrmhLynf4yMoMtj8AQF
#
#    spotify popularity  danceability  energy  key  loudness  mode  speechiness  \
# 0                  92         0.561   0.431   10    -8.810     1       0.0578
# 1                  90         0.593   0.503    8    -6.725     0       0.2200
# 2                  92         0.591   0.764    1    -5.484     1       0.0483
# 3                  95         0.563   0.664    9    -5.044     1       0.1540
# 4                  89         0.702   0.825    6    -3.787     0       0.0601
#
# ...

# %% [markdown]
# make new data frame with only danceability and spotify popularity scores

# %%
sdf_dance = sdf[['danceability', 'spotify popularity']]

# %% [markdown]
# sort the new data frame by danceability scores (0-1)

# %%
sdf_dance.sort_values('danceability')
# Out:
#     danceability  spotify popularity
# 28         0.380                  92
# 44         0.436                  86
# 17         0.442                  90
# 27         0.449                  86
# 43         0.453                  78
# 31         0.501                  88
# 7          0.514                  93
# 23         0.548                  90
# 0          0.561                  92
# 3          0.563                  95
# 16         0.586                  86
# 2          0.591                  92
# 1          0.593                  90
# 37         0.612                  92
# 22         0.644                  94
# 25         0.653                  87
# 26         0.662                  85
# 39         0.664                  93
# 48         0.667                  88
# 5          0.677                  90
# 14         0.680                  90
# 19         0.701                  89
# 4          0.702                  89
# 32         0.713                  82
# ...

# %% [markdown]
# make new data frame that is sorted by danceability scores

# %%
order_sdf=sdf_dance.sort_values('danceability')

# %% [markdown]
# check this new data frame looks correct

# %%
order_sdf
# Out:
#     danceability  spotify popularity
# 28         0.380                  92
# 44         0.436                  86
# 17         0.442                  90
# 27         0.449                  86
# 43         0.453                  78
# 31         0.501                  88
# 7          0.514                  93
# 23         0.548                  90
# 0          0.561                  92
# 3          0.563                  95
# 16         0.586                  86
# 2          0.591                  92
# 1          0.593                  90
# 37         0.612                  92
# 22         0.644                  94
# 25         0.653                  87
# 26         0.662                  85
# 39         0.664                  93
# 48         0.667                  88
# 5          0.677                  90
# 14         0.680                  90
# 19         0.701                  89
# 4          0.702                  89
# 32         0.713                  82
# ...

# %% [markdown]
# plot spotify popularity vs danceability scores

# %%
order_sdf.plot.line(x= 'danceability', y= 'spotify popularity')
# Out:
# <AxesSubplot:xlabel='danceability'>

# %% [markdown]
# tiktok data starts below

# %% [markdown]
# import the second data set I will be using which is for tiktok

# %%
ttdf = pd.read_csv('/Users/Leah/Desktop/TikTok_songs_2021.csv')

# %% [markdown]
# look at the headers for tiktok data

# %%
ttdf.head()
# Out:
#                                track_name    artist_name  artist_pop  \
# 0               STAY (with Justin Bieber)  The Kid LAROI          83
# 1  Peaches (feat. Daniel Caesar & Giveon)  Justin Bieber          90
# 2              edamame (feat. Rich Brian)          bbno$          72
# 3                     Here's Your Perfect   Jamie Miller          65
# 4                                It's You        Sezairi          57
#
#                         album  track_pop  danceability  energy  loudness  \
# 0   STAY (with Justin Bieber)         89         0.591   0.764    -5.484
# 1                     Justice         86         0.677   0.696    -6.181
# 2  edamame (feat. Rich Brian)         77         0.815   0.848    -4.704
# 3         Here's Your Perfect         77         0.558   0.454    -5.335
# 4                    It's You         73         0.630   0.456    -8.285
#
#    mode  key  speechiness  acousticness  instrumentalness  liveness  valence  \
# ...

# %% [markdown]
# rename tiktok popularity header

# %%
ttdf.rename(columns = {'track_pop':'tiktok popularity'}, inplace = True)

# %% [markdown]
# check that the renaming worked

# %%
ttdf.head()
# Out:
#                                track_name    artist_name  artist_pop  \
# 0               STAY (with Justin Bieber)  The Kid LAROI          83
# 1  Peaches (feat. Daniel Caesar & Giveon)  Justin Bieber          90
# 2              edamame (feat. Rich Brian)          bbno$          72
# 3                     Here's Your Perfect   Jamie Miller          65
# 4                                It's You        Sezairi          57
#
#                         album  tiktok popularity  danceability  energy  \
# 0   STAY (with Justin Bieber)                 89         0.591   0.764
# 1                     Justice                 86         0.677   0.696
# 2  edamame (feat. Rich Brian)                 77         0.815   0.848
# 3         Here's Your Perfect                 77         0.558   0.454
# 4                    It's You                 73         0.630   0.456
#
#    loudness  mode  key  speechiness  acousticness  instrumentalness  liveness  \
# ...

# %% [markdown]
# make new data frame with only danceability and tiktok popularity scores

# %%
ttdf_dance = ttdf[['tiktok popularity', 'danceability']]

# %% [markdown]
# sort the new data frame by danceability scores (0-1)

# %%
ttdf_dance.sort_values('danceability')
# Out:
#      tiktok popularity  danceability
# 7                   78         0.386
# 63                  86         0.395
# 183                 91         0.410
# 175                 74         0.435
# 102                 81         0.436
# ..                 ...           ...
# 189                 64         0.935
# 89                  67         0.939
# 27                  73         0.940
# 74                  40         0.945
# 51                  73         0.949
#
# [190 rows x 2 columns]

# %% [markdown]
# make new data frame that is sorted by danceability scores

# %%
order_ttdf=ttdf_dance.sort_values('danceability')

# %% [markdown]
# check this new data frame looks correct

# %%
order_ttdf
# Out:
#      tiktok popularity  danceability
# 7                   78         0.386
# 63                  86         0.395
# 183                 91         0.410
# 175                 74         0.435
# 102                 81         0.436
# ..                 ...           ...
# 189                 64         0.935
# 89                  67         0.939
# 27                  73         0.940
# 74                  40         0.945
# 51                  73         0.949
#
# [190 rows x 2 columns]

# %% [markdown]
# plot tiktok popularity vs danceability

# %%
order_ttdf.plot.line(x= 'danceability', y= 'tiktok popularity')
# Out:
# <AxesSubplot:xlabel='danceability'>

# %% [markdown]
# merge the order_sdf and the order_ttdf data frames on danceability scores

# %%
comb_df=pd.merge(order_sdf, order_ttdf, how='outer', on='danceability')

# %% [markdown]
# display the resulting table

# %%
comb_df
# Out:
#      danceability  spotify popularity  tiktok popularity
# 0           0.380                92.0                NaN
# 1           0.436                86.0               81.0
# 2           0.442                90.0               88.0
# 3           0.449                86.0               83.0
# 4           0.453                78.0                NaN
# ..            ...                 ...                ...
# 205         0.935                 NaN               64.0
# 206         0.939                 NaN               67.0
# 207         0.940                 NaN               73.0
# 208         0.945                 NaN               40.0
# 209         0.949                 NaN               73.0
#
# [210 rows x 3 columns]

# %% [markdown]
# ## plot the merged dataframe

# %%
comb_df.plot.line(x= 'danceability', y= ['tiktok popularity','spotify popularity'], 
title= 'Danceability Affect on Popularity for TikTok and Spotify in 2021',
xlabel= 'Danceability Score (0-1)',
ylabel= 'Popularity Score (0-100)')
# Out:
# <AxesSubplot:title={'center':'Danceability Affect on Popularity for TikTok and Spotify in 2021'}, xlabel='Danceability Score (0-1)', ylabel='Popularity Score (0-100)'>

# %% [markdown]
# this is my graph looking at how danceability relates to popularity scores on tiktok and spotify
